# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.autograd import Variable
from utils import create_dataloader

# %% [markdown]
# ### Creating config object (argparse workaround)

# %%
class Config:
    pass

config = Config()
config.mnist_path = None
config.batch_size = 16
config.num_workers = 3
config.num_epochs = 10
config.noise_size = 50
config.print_freq = 100

# %% [markdown]
# ### Create dataloder

# %%
dataloader = create_dataloader(config)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
len(dataloader)
# Out:
# 3750

# %%
for image, cat in dataloader:
    break

# %%
image.size()
# Out:
# torch.Size([16, 1, 28, 28])

# %%
28*28
# Out:
# 784

# %% [markdown]
# ### Create generator and discriminator

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential( 
            nn.Linear(config.noise_size, 200),
            nn.ReLU(inplace=True),
            nn.Linear(200, 28*28),
            nn.Sigmoid())
        
    def forward(self, x):
        return self.model(x)
    
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(28*28, 200),
            nn.ReLU(inplace=True),
            nn.Linear(200, 50),
            nn.ReLU(inplace=True),
            nn.Linear(50, 1), 
            nn.Sigmoid())
    def forward(self, x):
        return self.model(x)

# %%
generator = Generator()
discriminator = Discriminator()

# %% [markdown]
# ### Create optimizers and loss

# %%
optim_G = optim.Adam(params=generator.parameters(), lr=0.0001)
optim_D = optim.Adam(params=discriminator.parameters(), lr=0.0001)

criterion = nn.BCELoss()

# %% [markdown]
# ### Create necessary variables

# %%
input = Variable(torch.FloatTensor(config.batch_size, 28*28))
noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size))
fixed_noise = Variable(torch.FloatTensor(config.batch_size, config.noise_size).normal_(0, 1))
label = Variable(torch.FloatTensor(config.batch_size))
real_label = 1
fake_label = 0

# %% [markdown]
# ### Задание
#
# 1) Посмотрите на реализацию GAN
#
# 2) Поменяйте ее, чтобы получился LSGAN https://arxiv.org/pdf/1611.04076v2.pdf
#
# 3) Попробуйте оба GAN и LSGAN на CelebA http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html
#
# 4) Напишите отчет что попробовали, какие результаты получили, как вам кажется надо обучать GAN, чтобы добиться сходимости?
#
# Обязательны графики.

# %% [markdown]
# ### GAN

# %%
for epoch in range(config.num_epochs):
    for iteration, (images, cat) in enumerate(dataloader):
        ####### 
        # Discriminator stage: maximize log(D(x)) + log(1 - D(G(z))) 
        #######
        discriminator.zero_grad()
        
        # real
        label.data.fill_(real_label)
        input.data.copy_(images)
        output = discriminator(input)
        errD_x = criterion(output, label)
        errD_x.backward()
        
        # fake 
        noise.data.normal_(0, 1)
        fake = generator(noise)
        label.data.fill_(fake_label)
        output = discriminator(fake.detach())
        errD_z = criterion(output, label)
        errD_z.backward()
        
        optim_D.step()
        
        ####### 
        # Generator stage: maximize log(D(G(x))
        #######
        generator.zero_grad()
        label.data.fill_(real_label)
        output = discriminator(fake)
        errG = criterion(output, label)
        errG.backward()
        
        optim_G.step()
        
        if (iteration+1) % config.print_freq == 0:
            print('Epoch:{} Iter: {} errD_x: {:.2f} errD_z: {:.2f} errG: {:.2f}'.format(epoch+1,
                                                                                            iteration+1, 
                                                                                            errD_x.data[0],
                                                                                            errD_z.data[0], 
                                                                                            errG.data[0]))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:10: UserWarning: src is not broadcastable to dst, but they have the same number of elements.  Falling back to deprecated pointwise behavior.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:1189: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Epoch:1 Iter: 100 errD_x: 0.15 errD_z: 0.05 errG: 3.15
# Epoch:1 Iter: 200 errD_x: 0.06 errD_z: 0.01 errG: 4.91
# Epoch:1 Iter: 300 errD_x: 0.09 errD_z: 0.03 errG: 5.31
# Epoch:1 Iter: 400 errD_x: 0.34 errD_z: 0.15 errG: 3.85
# Epoch:1 Iter: 500 errD_x: 0.19 errD_z: 0.28 errG: 1.90
# Epoch:1 Iter: 600 errD_x: 0.19 errD_z: 0.06 errG: 3.31
# Epoch:1 Iter: 700 errD_x: 0.10 errD_z: 0.04 errG: 3.61
# Epoch:1 Iter: 800 errD_x: 0.04 errD_z: 0.03 errG: 3.69
# Epoch:1 Iter: 900 errD_x: 0.02 errD_z: 0.04 errG: 3.54
# Epoch:1 Iter: 1000 errD_x: 0.03 errD_z: 0.05 errG: 3.50
# Epoch:1 Iter: 1100 errD_x: 0.03 errD_z: 0.04 errG: 3.69
# Epoch:1 Iter: 1200 errD_x: 0.04 errD_z: 0.05 errG: 3.29
# Epoch:1 Iter: 1300 errD_x: 0.03 errD_z: 0.08 errG: 2.79
# Epoch:1 Iter: 1400 errD_x: 0.04 errD_z: 0.12 errG: 2.34
# Epoch:1 Iter: 1500 errD_x: 0.11 errD_z: 0.20 errG: 1.98
# Epoch:1 Iter: 1600 errD_x: 0.22 errD_z: 0.09 errG: 2.69
# Epoch:1 Iter: 1700 errD_x: 0.08 errD_z: 0.20 errG: 1.95
# Epoch:1 Iter: 1800 errD_x: 0.01 errD_z: 0.12 errG: 2.51
# Epoch:1 Iter: 1900 errD_x: 0.08 errD_z: 0.13 errG: 2.44
# Epoch:1 Iter: 2000 errD_x: 0.01 errD_z: 0.14 errG: 2.40
# Epoch:1 Iter: 2100 errD_x: 0.00 errD_z: 0.08 errG: 2.85
# Epoch:1 Iter: 2200 errD_x: 0.18 errD_z: 0.10 errG: 2.71
# Epoch:1 Iter: 2300 errD_x: 0.01 errD_z: 0.05 errG: 3.30
# Epoch:1 Iter: 2400 errD_x: 0.03 errD_z: 0.06 errG: 3.25
# Epoch:1 Iter: 2500 errD_x: 0.05 errD_z: 0.04 errG: 3.40
# Epoch:1 Iter: 2600 errD_x: 0.02 errD_z: 0.09 errG: 3.13
# Epoch:1 Iter: 2700 errD_x: 0.00 errD_z: 0.03 errG: 3.85
# Epoch:1 Iter: 2800 errD_x: 0.05 errD_z: 0.07 errG: 3.36
# Epoch:1 Iter: 2900 errD_x: 0.32 errD_z: 0.04 errG: 4.23
# Epoch:1 Iter: 3000 errD_x: 0.00 errD_z: 0.01 errG: 5.16
# Epoch:1 Iter: 3100 errD_x: 0.00 errD_z: 0.02 errG: 4.63
# Epoch:1 Iter: 3200 errD_x: 0.02 errD_z: 0.04 errG: 4.53
# Epoch:1 Iter: 3300 errD_x: 0.01 errD_z: 0.03 errG: 4.72
# Epoch:1 Iter: 3400 errD_x: 0.15 errD_z: 0.01 errG: 5.70
# Epoch:1 Iter: 3500 errD_x: 0.02 errD_z: 0.15 errG: 3.93
# Epoch:1 Iter: 3600 errD_x: 0.03 errD_z: 0.09 errG: 3.61
# Epoch:1 Iter: 3700 errD_x: 0.12 errD_z: 0.02 errG: 4.79
# Epoch:2 Iter: 100 errD_x: 0.00 errD_z: 0.01 errG: 5.77
# Epoch:2 Iter: 200 errD_x: 0.00 errD_z: 0.01 errG: 6.44
# Epoch:2 Iter: 300 errD_x: 0.02 errD_z: 0.07 errG: 4.32
# Epoch:2 Iter: 400 errD_x: 0.11 errD_z: 0.01 errG: 5.74
# Epoch:2 Iter: 500 errD_x: 0.02 errD_z: 0.04 errG: 5.19
# Epoch:2 Iter: 600 errD_x: 0.17 errD_z: 0.08 errG: 5.12
# Epoch:2 Iter: 700 errD_x: 0.04 errD_z: 0.04 errG: 4.39
# Epoch:2 Iter: 800 errD_x: 0.01 errD_z: 0.05 errG: 4.81
# Epoch:2 Iter: 900 errD_x: 0.13 errD_z: 0.04 errG: 4.75
# Epoch:2 Iter: 1000 errD_x: 0.01 errD_z: 0.10 errG: 3.94
# Epoch:2 Iter: 1100 errD_x: 0.02 errD_z: 0.07 errG: 3.74
# Epoch:2 Iter: 1200 errD_x: 0.02 errD_z: 0.06 errG: 4.06
# Epoch:2 Iter: 1300 errD_x: 0.00 errD_z: 0.01 errG: 4.69
# Epoch:2 Iter: 1400 errD_x: 0.00 errD_z: 0.19 errG: 5.24
# Epoch:2 Iter: 1500 errD_x: 0.23 errD_z: 0.07 errG: 3.54
# Epoch:2 Iter: 1600 errD_x: 0.09 errD_z: 0.03 errG: 3.88
# Epoch:2 Iter: 1700 errD_x: 0.12 errD_z: 0.04 errG: 4.26
# Epoch:2 Iter: 1800 errD_x: 0.00 errD_z: 0.02 errG: 5.00
# Epoch:2 Iter: 1900 errD_x: 0.14 errD_z: 0.02 errG: 5.04
# Epoch:2 Iter: 2000 errD_x: 0.02 errD_z: 0.21 errG: 4.21
# Epoch:2 Iter: 2100 errD_x: 0.16 errD_z: 0.06 errG: 4.81
# Epoch:2 Iter: 2200 errD_x: 0.00 errD_z: 0.02 errG: 4.86
# Epoch:2 Iter: 2300 errD_x: 0.17 errD_z: 0.01 errG: 4.98
# Epoch:2 Iter: 2400 errD_x: 0.02 errD_z: 0.04 errG: 4.52
# Epoch:2 Iter: 2500 errD_x: 0.06 errD_z: 0.08 errG: 3.62
# Epoch:2 Iter: 2600 errD_x: 0.01 errD_z: 0.03 errG: 3.77
# Epoch:2 Iter: 2700 errD_x: 0.05 errD_z: 0.07 errG: 3.71
# Epoch:2 Iter: 2800 errD_x: 0.09 errD_z: 0.03 errG: 4.10
# Epoch:2 Iter: 2900 errD_x: 0.01 errD_z: 0.02 errG: 4.61
# Epoch:2 Iter: 3000 errD_x: 0.02 errD_z: 0.04 errG: 5.09
# Epoch:2 Iter: 3100 errD_x: 0.10 errD_z: 0.00 errG: 6.27
# Epoch:2 Iter: 3200 errD_x: 0.23 errD_z: 0.01 errG: 5.67
# Epoch:2 Iter: 3300 errD_x: 0.00 errD_z: 0.02 errG: 4.55
# Epoch:2 Iter: 3400 errD_x: 0.00 errD_z: 0.04 errG: 4.23
# Epoch:2 Iter: 3500 errD_x: 0.00 errD_z: 0.11 errG: 3.73
# Epoch:2 Iter: 3600 errD_x: 0.01 errD_z: 0.03 errG: 4.45
# Epoch:2 Iter: 3700 errD_x: 0.20 errD_z: 0.01 errG: 4.96
# Epoch:3 Iter: 100 errD_x: 0.00 errD_z: 0.02 errG: 5.34
# Epoch:3 Iter: 200 errD_x: 0.07 errD_z: 0.01 errG: 5.45
# Epoch:3 Iter: 300 errD_x: 0.00 errD_z: 0.04 errG: 4.69
# Epoch:3 Iter: 400 errD_x: 0.17 errD_z: 0.01 errG: 5.01
# Epoch:3 Iter: 500 errD_x: 0.00 errD_z: 0.04 errG: 3.78
# Epoch:3 Iter: 600 errD_x: 0.37 errD_z: 0.01 errG: 4.63
# Epoch:3 Iter: 700 errD_x: 0.09 errD_z: 0.02 errG: 5.05
# Epoch:3 Iter: 800 errD_x: 0.01 errD_z: 0.13 errG: 3.77
# Epoch:3 Iter: 900 errD_x: 0.00 errD_z: 0.02 errG: 4.80
# Epoch:3 Iter: 1000 errD_x: 0.01 errD_z: 0.02 errG: 4.79
# Epoch:3 Iter: 1100 errD_x: 0.01 errD_z: 0.03 errG: 4.25
# Epoch:3 Iter: 1200 errD_x: 0.05 errD_z: 0.07 errG: 4.27
# Epoch:3 Iter: 1300 errD_x: 0.01 errD_z: 0.04 errG: 4.97
# Epoch:3 Iter: 1400 errD_x: 0.00 errD_z: 0.06 errG: 4.46
# Epoch:3 Iter: 1500 errD_x: 0.01 errD_z: 0.04 errG: 5.00
# Epoch:3 Iter: 1600 errD_x: 0.11 errD_z: 0.02 errG: 4.84
# Epoch:3 Iter: 1700 errD_x: 0.01 errD_z: 0.17 errG: 3.64
# Epoch:3 Iter: 1800 errD_x: 0.01 errD_z: 0.05 errG: 4.00
# Epoch:3 Iter: 1900 errD_x: 0.00 errD_z: 0.00 errG: 6.23
# Epoch:3 Iter: 2000 errD_x: 0.02 errD_z: 0.04 errG: 4.11
# Epoch:3 Iter: 2100 errD_x: 0.00 errD_z: 0.11 errG: 3.70
# Epoch:3 Iter: 2200 errD_x: 0.00 errD_z: 0.02 errG: 4.65
# Epoch:3 Iter: 2300 errD_x: 0.04 errD_z: 0.06 errG: 4.72
# Epoch:3 Iter: 2400 errD_x: 0.00 errD_z: 0.04 errG: 4.44
# Epoch:3 Iter: 2500 errD_x: 0.00 errD_z: 0.01 errG: 6.36
# Epoch:3 Iter: 2600 errD_x: 0.01 errD_z: 0.01 errG: 5.92
# Epoch:3 Iter: 2700 errD_x: 0.01 errD_z: 0.02 errG: 4.38
# Epoch:3 Iter: 2800 errD_x: 0.18 errD_z: 0.02 errG: 5.47
# Epoch:3 Iter: 2900 errD_x: 0.02 errD_z: 0.01 errG: 5.52
# Epoch:3 Iter: 3000 errD_x: 0.09 errD_z: 0.03 errG: 4.30
# Epoch:3 Iter: 3100 errD_x: 0.00 errD_z: 0.06 errG: 4.35
# Epoch:3 Iter: 3200 errD_x: 0.01 errD_z: 0.03 errG: 4.59
# Epoch:3 Iter: 3300 errD_x: 0.01 errD_z: 0.03 errG: 3.95
# Epoch:3 Iter: 3400 errD_x: 0.01 errD_z: 0.08 errG: 5.59
# Epoch:3 Iter: 3500 errD_x: 0.00 errD_z: 0.08 errG: 4.91
# Epoch:3 Iter: 3600 errD_x: 0.10 errD_z: 0.01 errG: 6.17
# Epoch:3 Iter: 3700 errD_x: 0.07 errD_z: 0.01 errG: 6.71
# Epoch:4 Iter: 100 errD_x: 0.13 errD_z: 0.11 errG: 5.03
# Epoch:4 Iter: 200 errD_x: 0.00 errD_z: 0.07 errG: 5.32
# Epoch:4 Iter: 300 errD_x: 0.01 errD_z: 0.00 errG: 7.18
# Epoch:4 Iter: 400 errD_x: 0.06 errD_z: 0.10 errG: 4.67
# Epoch:4 Iter: 500 errD_x: 0.03 errD_z: 0.02 errG: 5.80
# Epoch:4 Iter: 600 errD_x: 0.01 errD_z: 0.08 errG: 5.72
# Epoch:4 Iter: 700 errD_x: 0.03 errD_z: 0.01 errG: 6.08
# Epoch:4 Iter: 800 errD_x: 0.28 errD_z: 0.03 errG: 5.05
# Epoch:4 Iter: 900 errD_x: 0.40 errD_z: 0.00 errG: 6.71
# Epoch:4 Iter: 1000 errD_x: 0.09 errD_z: 0.04 errG: 5.76
# Epoch:4 Iter: 1100 errD_x: 0.01 errD_z: 0.05 errG: 4.63
# Epoch:4 Iter: 1200 errD_x: 0.08 errD_z: 0.05 errG: 3.83
# Epoch:4 Iter: 1300 errD_x: 0.16 errD_z: 0.20 errG: 4.62
# Epoch:4 Iter: 1400 errD_x: 0.04 errD_z: 0.03 errG: 5.07
# Epoch:4 Iter: 1500 errD_x: 0.01 errD_z: 0.03 errG: 5.34
# Epoch:4 Iter: 1600 errD_x: 0.01 errD_z: 0.05 errG: 5.03
# Epoch:4 Iter: 1700 errD_x: 0.01 errD_z: 0.10 errG: 4.19
# Epoch:4 Iter: 1800 errD_x: 0.10 errD_z: 0.05 errG: 4.30
# Epoch:4 Iter: 1900 errD_x: 0.15 errD_z: 0.04 errG: 4.05
# Epoch:4 Iter: 2000 errD_x: 0.14 errD_z: 0.06 errG: 3.84
# Epoch:4 Iter: 2100 errD_x: 0.02 errD_z: 0.13 errG: 3.44
# Epoch:4 Iter: 2200 errD_x: 0.11 errD_z: 0.01 errG: 5.91
# Epoch:4 Iter: 2300 errD_x: 0.19 errD_z: 0.02 errG: 4.66
# Epoch:4 Iter: 2400 errD_x: 0.08 errD_z: 0.07 errG: 4.22
# Epoch:4 Iter: 2500 errD_x: 0.10 errD_z: 0.01 errG: 6.26
# Epoch:4 Iter: 2600 errD_x: 0.03 errD_z: 0.02 errG: 5.27
# Epoch:4 Iter: 2700 errD_x: 0.03 errD_z: 0.04 errG: 4.29
# Epoch:4 Iter: 2800 errD_x: 0.07 errD_z: 0.05 errG: 4.72
# Epoch:4 Iter: 2900 errD_x: 0.08 errD_z: 0.04 errG: 4.34
# Epoch:4 Iter: 3000 errD_x: 0.02 errD_z: 0.04 errG: 4.24
# Epoch:4 Iter: 3100 errD_x: 0.09 errD_z: 0.06 errG: 4.45
# Epoch:4 Iter: 3200 errD_x: 0.05 errD_z: 0.06 errG: 4.39
# Epoch:4 Iter: 3300 errD_x: 0.05 errD_z: 0.05 errG: 4.31
# Epoch:4 Iter: 3400 errD_x: 0.03 errD_z: 0.08 errG: 4.40
# Epoch:4 Iter: 3500 errD_x: 0.03 errD_z: 0.04 errG: 4.73
# Epoch:4 Iter: 3600 errD_x: 0.20 errD_z: 0.05 errG: 4.98
# Epoch:4 Iter: 3700 errD_x: 0.01 errD_z: 0.03 errG: 5.38
# Epoch:5 Iter: 100 errD_x: 0.06 errD_z: 0.04 errG: 4.78
# Epoch:5 Iter: 200 errD_x: 0.06 errD_z: 0.03 errG: 4.39
# Epoch:5 Iter: 300 errD_x: 0.04 errD_z: 0.01 errG: 4.85
# Epoch:5 Iter: 400 errD_x: 0.14 errD_z: 0.02 errG: 4.76
# Epoch:5 Iter: 500 errD_x: 0.20 errD_z: 0.00 errG: 6.28
# Epoch:5 Iter: 600 errD_x: 0.14 errD_z: 0.02 errG: 4.77
# Epoch:5 Iter: 700 errD_x: 0.00 errD_z: 0.08 errG: 4.68
# Epoch:5 Iter: 800 errD_x: 0.03 errD_z: 0.05 errG: 4.92
# Epoch:5 Iter: 900 errD_x: 0.03 errD_z: 0.07 errG: 4.30
# Epoch:5 Iter: 1000 errD_x: 0.11 errD_z: 0.06 errG: 4.58
# Epoch:5 Iter: 1100 errD_x: 0.42 errD_z: 0.01 errG: 6.57
# Epoch:5 Iter: 1200 errD_x: 0.09 errD_z: 0.01 errG: 5.54
# Epoch:5 Iter: 1300 errD_x: 0.01 errD_z: 0.14 errG: 3.78
# Epoch:5 Iter: 1400 errD_x: 0.06 errD_z: 0.03 errG: 5.42
# Epoch:5 Iter: 1500 errD_x: 0.09 errD_z: 0.14 errG: 4.71
# Epoch:5 Iter: 1600 errD_x: 0.13 errD_z: 0.01 errG: 6.18
# Epoch:5 Iter: 1700 errD_x: 0.00 errD_z: 0.04 errG: 4.60
# Epoch:5 Iter: 1800 errD_x: 0.08 errD_z: 0.07 errG: 4.13
# Epoch:5 Iter: 1900 errD_x: 0.20 errD_z: 0.07 errG: 3.67
# Epoch:5 Iter: 2000 errD_x: 0.04 errD_z: 0.03 errG: 5.30
# Epoch:5 Iter: 2100 errD_x: 0.06 errD_z: 0.01 errG: 6.27
# Epoch:5 Iter: 2200 errD_x: 0.01 errD_z: 0.05 errG: 4.61
# Epoch:5 Iter: 2300 errD_x: 0.04 errD_z: 0.03 errG: 4.49
# Epoch:5 Iter: 2400 errD_x: 0.01 errD_z: 0.05 errG: 5.35
# Epoch:5 Iter: 2500 errD_x: 0.03 errD_z: 0.04 errG: 4.73
# Epoch:5 Iter: 2600 errD_x: 0.04 errD_z: 0.01 errG: 5.67
# Epoch:5 Iter: 2700 errD_x: 0.07 errD_z: 0.02 errG: 5.66
# Epoch:5 Iter: 2800 errD_x: 0.02 errD_z: 0.01 errG: 6.10
# Epoch:5 Iter: 2900 errD_x: 0.19 errD_z: 0.01 errG: 5.75
# Epoch:5 Iter: 3000 errD_x: 0.02 errD_z: 0.09 errG: 5.40
# Epoch:5 Iter: 3100 errD_x: 0.00 errD_z: 0.01 errG: 5.67
# Epoch:5 Iter: 3200 errD_x: 0.02 errD_z: 0.21 errG: 3.63
# Epoch:5 Iter: 3300 errD_x: 0.08 errD_z: 0.05 errG: 4.39
# Epoch:5 Iter: 3400 errD_x: 0.01 errD_z: 0.06 errG: 4.78
# Epoch:5 Iter: 3500 errD_x: 0.01 errD_z: 0.02 errG: 4.83
# Epoch:5 Iter: 3600 errD_x: 0.02 errD_z: 0.07 errG: 5.56
# Epoch:5 Iter: 3700 errD_x: 0.04 errD_z: 0.17 errG: 4.41
# Epoch:6 Iter: 100 errD_x: 0.14 errD_z: 0.06 errG: 4.80
# Epoch:6 Iter: 200 errD_x: 0.02 errD_z: 0.05 errG: 4.87
# Epoch:6 Iter: 300 errD_x: 0.03 errD_z: 0.08 errG: 4.71
# Epoch:6 Iter: 400 errD_x: 0.08 errD_z: 0.04 errG: 4.68
# Epoch:6 Iter: 500 errD_x: 0.01 errD_z: 0.11 errG: 4.27
# Epoch:6 Iter: 600 errD_x: 0.00 errD_z: 0.13 errG: 5.01
# Epoch:6 Iter: 700 errD_x: 0.06 errD_z: 0.08 errG: 4.66
# Epoch:6 Iter: 800 errD_x: 0.44 errD_z: 0.03 errG: 5.18
# Epoch:6 Iter: 900 errD_x: 0.00 errD_z: 0.14 errG: 4.37
# Epoch:6 Iter: 1000 errD_x: 0.30 errD_z: 0.14 errG: 3.29
# Epoch:6 Iter: 1100 errD_x: 0.09 errD_z: 0.13 errG: 3.25
# Epoch:6 Iter: 1200 errD_x: 0.02 errD_z: 0.10 errG: 4.84
# Epoch:6 Iter: 1300 errD_x: 0.07 errD_z: 0.02 errG: 6.35
# Epoch:6 Iter: 1400 errD_x: 0.13 errD_z: 0.03 errG: 4.53
# Epoch:6 Iter: 1500 errD_x: 0.03 errD_z: 0.01 errG: 5.13
# Epoch:6 Iter: 1600 errD_x: 0.11 errD_z: 0.16 errG: 4.89
# Epoch:6 Iter: 1700 errD_x: 0.09 errD_z: 0.03 errG: 4.54
# Epoch:6 Iter: 1800 errD_x: 0.24 errD_z: 0.04 errG: 4.85
# Epoch:6 Iter: 1900 errD_x: 0.01 errD_z: 0.05 errG: 4.29
# Epoch:6 Iter: 2000 errD_x: 0.77 errD_z: 0.03 errG: 5.30
# Epoch:6 Iter: 2100 errD_x: 0.23 errD_z: 0.08 errG: 4.80
# Epoch:6 Iter: 2200 errD_x: 0.14 errD_z: 0.30 errG: 3.91
# Epoch:6 Iter: 2300 errD_x: 0.07 errD_z: 0.22 errG: 3.65
# Epoch:6 Iter: 2400 errD_x: 0.21 errD_z: 0.02 errG: 5.55
# Epoch:6 Iter: 2500 errD_x: 0.06 errD_z: 0.00 errG: 7.35
# Epoch:6 Iter: 2600 errD_x: 0.00 errD_z: 0.39 errG: 3.08
# Epoch:6 Iter: 2700 errD_x: 0.04 errD_z: 0.08 errG: 4.40
# Epoch:6 Iter: 2800 errD_x: 0.11 errD_z: 0.03 errG: 5.47
# Epoch:6 Iter: 2900 errD_x: 0.16 errD_z: 0.03 errG: 5.70
# Epoch:6 Iter: 3000 errD_x: 0.04 errD_z: 0.23 errG: 4.06
# Epoch:6 Iter: 3100 errD_x: 0.04 errD_z: 0.06 errG: 4.72
# Epoch:6 Iter: 3200 errD_x: 0.32 errD_z: 0.01 errG: 5.95
# Epoch:6 Iter: 3300 errD_x: 0.05 errD_z: 0.13 errG: 4.08
# Epoch:6 Iter: 3400 errD_x: 0.14 errD_z: 0.08 errG: 4.18
# Epoch:6 Iter: 3500 errD_x: 0.10 errD_z: 0.04 errG: 4.94
# Epoch:6 Iter: 3600 errD_x: 0.14 errD_z: 0.12 errG: 3.22
# Epoch:6 Iter: 3700 errD_x: 0.14 errD_z: 0.02 errG: 5.54
# Epoch:7 Iter: 100 errD_x: 0.30 errD_z: 0.04 errG: 4.38
# Epoch:7 Iter: 200 errD_x: 0.21 errD_z: 0.12 errG: 4.09
# Epoch:7 Iter: 300 errD_x: 0.08 errD_z: 0.05 errG: 5.70
# Epoch:7 Iter: 400 errD_x: 0.02 errD_z: 0.03 errG: 4.85
# Epoch:7 Iter: 500 errD_x: 0.02 errD_z: 0.16 errG: 4.11
# Epoch:7 Iter: 600 errD_x: 0.00 errD_z: 0.02 errG: 5.26
# Epoch:7 Iter: 700 errD_x: 0.21 errD_z: 0.02 errG: 6.28
# Epoch:7 Iter: 800 errD_x: 0.01 errD_z: 0.20 errG: 4.15
# Epoch:7 Iter: 900 errD_x: 0.24 errD_z: 0.08 errG: 5.36
# Epoch:7 Iter: 1000 errD_x: 0.16 errD_z: 0.08 errG: 3.48
# Epoch:7 Iter: 1100 errD_x: 0.16 errD_z: 0.24 errG: 2.71
# Epoch:7 Iter: 1200 errD_x: 0.54 errD_z: 0.04 errG: 4.47
# Epoch:7 Iter: 1300 errD_x: 0.03 errD_z: 0.03 errG: 5.15
# Epoch:7 Iter: 1400 errD_x: 0.00 errD_z: 0.14 errG: 3.92
# Epoch:7 Iter: 1500 errD_x: 0.06 errD_z: 0.27 errG: 5.49
# Epoch:7 Iter: 1600 errD_x: 0.03 errD_z: 0.16 errG: 4.33
# Epoch:7 Iter: 1700 errD_x: 0.17 errD_z: 0.05 errG: 5.37
# Epoch:7 Iter: 1800 errD_x: 0.01 errD_z: 0.09 errG: 4.33
# Epoch:7 Iter: 1900 errD_x: 0.52 errD_z: 0.02 errG: 4.31
# Epoch:7 Iter: 2000 errD_x: 0.02 errD_z: 0.04 errG: 5.42
# Epoch:7 Iter: 2100 errD_x: 0.03 errD_z: 0.02 errG: 4.89
# Epoch:7 Iter: 2200 errD_x: 0.14 errD_z: 0.35 errG: 3.37
# Epoch:7 Iter: 2300 errD_x: 0.04 errD_z: 0.07 errG: 4.61
# Epoch:7 Iter: 2400 errD_x: 0.01 errD_z: 0.23 errG: 3.68
# Epoch:7 Iter: 2500 errD_x: 0.26 errD_z: 0.02 errG: 5.47
# Epoch:7 Iter: 2600 errD_x: 0.21 errD_z: 0.09 errG: 3.85
# Epoch:7 Iter: 2700 errD_x: 0.02 errD_z: 0.13 errG: 3.03
# Epoch:7 Iter: 2800 errD_x: 0.03 errD_z: 0.19 errG: 3.64
# Epoch:7 Iter: 2900 errD_x: 0.10 errD_z: 0.02 errG: 5.69
# Epoch:7 Iter: 3000 errD_x: 0.01 errD_z: 0.12 errG: 4.40
# Epoch:7 Iter: 3100 errD_x: 0.00 errD_z: 0.20 errG: 5.24
# Epoch:7 Iter: 3200 errD_x: 0.19 errD_z: 0.08 errG: 3.81
# Epoch:7 Iter: 3300 errD_x: 0.05 errD_z: 0.12 errG: 4.67
# Epoch:7 Iter: 3400 errD_x: 0.56 errD_z: 0.13 errG: 5.31
# Epoch:7 Iter: 3500 errD_x: 0.02 errD_z: 0.11 errG: 3.40
# Epoch:7 Iter: 3600 errD_x: 0.01 errD_z: 0.11 errG: 3.94
# Epoch:7 Iter: 3700 errD_x: 0.00 errD_z: 0.06 errG: 3.82
# Epoch:8 Iter: 100 errD_x: 0.12 errD_z: 0.12 errG: 3.94
# Epoch:8 Iter: 200 errD_x: 0.44 errD_z: 0.01 errG: 6.34
# Epoch:8 Iter: 300 errD_x: 0.15 errD_z: 0.09 errG: 5.24
# Epoch:8 Iter: 400 errD_x: 0.03 errD_z: 0.02 errG: 5.44
# Epoch:8 Iter: 500 errD_x: 0.61 errD_z: 0.02 errG: 4.98
# Epoch:8 Iter: 600 errD_x: 0.00 errD_z: 0.01 errG: 5.70
# Epoch:8 Iter: 700 errD_x: 0.04 errD_z: 0.03 errG: 5.32
# Epoch:8 Iter: 800 errD_x: 0.32 errD_z: 0.03 errG: 4.84
# Epoch:8 Iter: 900 errD_x: 0.44 errD_z: 0.01 errG: 6.10
# Epoch:8 Iter: 1000 errD_x: 0.34 errD_z: 0.07 errG: 4.04
# Epoch:8 Iter: 1100 errD_x: 0.30 errD_z: 0.04 errG: 4.36
# Epoch:8 Iter: 1200 errD_x: 0.07 errD_z: 0.07 errG: 4.32
# Epoch:8 Iter: 1300 errD_x: 0.28 errD_z: 0.02 errG: 4.92
# Epoch:8 Iter: 1400 errD_x: 0.22 errD_z: 0.02 errG: 4.81
# Epoch:8 Iter: 1500 errD_x: 0.00 errD_z: 0.07 errG: 3.95
# Epoch:8 Iter: 1600 errD_x: 0.01 errD_z: 0.13 errG: 4.05
# Epoch:8 Iter: 1700 errD_x: 0.01 errD_z: 0.05 errG: 4.67
# Epoch:8 Iter: 1800 errD_x: 0.09 errD_z: 0.10 errG: 4.95
# Epoch:8 Iter: 1900 errD_x: 0.06 errD_z: 0.09 errG: 3.45
# Epoch:8 Iter: 2000 errD_x: 0.08 errD_z: 0.11 errG: 3.76
# Epoch:8 Iter: 2100 errD_x: 0.02 errD_z: 0.07 errG: 4.16
# Epoch:8 Iter: 2200 errD_x: 0.21 errD_z: 0.02 errG: 5.20
# Epoch:8 Iter: 2300 errD_x: 0.02 errD_z: 0.09 errG: 4.77
# Epoch:8 Iter: 2400 errD_x: 0.09 errD_z: 0.01 errG: 5.15
# Epoch:8 Iter: 2500 errD_x: 0.00 errD_z: 0.13 errG: 2.84
# Epoch:8 Iter: 2600 errD_x: 0.01 errD_z: 0.18 errG: 3.21
# Epoch:8 Iter: 2700 errD_x: 0.00 errD_z: 0.08 errG: 4.70
# Epoch:8 Iter: 2800 errD_x: 0.34 errD_z: 0.13 errG: 5.58
# Epoch:8 Iter: 2900 errD_x: 0.40 errD_z: 0.01 errG: 5.39
# Epoch:8 Iter: 3000 errD_x: 0.01 errD_z: 0.06 errG: 4.69
# Epoch:8 Iter: 3100 errD_x: 0.05 errD_z: 0.05 errG: 4.24
# Epoch:8 Iter: 3200 errD_x: 0.11 errD_z: 0.04 errG: 4.99
# Epoch:8 Iter: 3300 errD_x: 0.01 errD_z: 0.03 errG: 5.01
# Epoch:8 Iter: 3400 errD_x: 0.21 errD_z: 0.02 errG: 4.70
# Epoch:8 Iter: 3500 errD_x: 0.05 errD_z: 0.09 errG: 3.96
# Epoch:8 Iter: 3600 errD_x: 0.05 errD_z: 0.13 errG: 3.91
# Epoch:8 Iter: 3700 errD_x: 0.00 errD_z: 0.07 errG: 6.03
# Epoch:9 Iter: 100 errD_x: 0.11 errD_z: 0.07 errG: 4.54
# Epoch:9 Iter: 200 errD_x: 0.02 errD_z: 0.02 errG: 4.58
# Epoch:9 Iter: 300 errD_x: 0.15 errD_z: 0.09 errG: 3.95
# Epoch:9 Iter: 400 errD_x: 0.06 errD_z: 0.04 errG: 4.87
# Epoch:9 Iter: 500 errD_x: 0.09 errD_z: 0.02 errG: 5.83
# Epoch:9 Iter: 600 errD_x: 0.01 errD_z: 0.04 errG: 4.22
# Epoch:9 Iter: 700 errD_x: 0.14 errD_z: 0.26 errG: 4.32
# Epoch:9 Iter: 800 errD_x: 0.01 errD_z: 0.04 errG: 4.23
# Epoch:9 Iter: 900 errD_x: 0.14 errD_z: 0.06 errG: 4.44
# Epoch:9 Iter: 1000 errD_x: 0.30 errD_z: 0.04 errG: 4.57
# Epoch:9 Iter: 1100 errD_x: 0.05 errD_z: 0.08 errG: 4.14
# Epoch:9 Iter: 1200 errD_x: 0.01 errD_z: 0.07 errG: 4.36
# Epoch:9 Iter: 1300 errD_x: 0.00 errD_z: 0.20 errG: 3.24
# Epoch:9 Iter: 1400 errD_x: 0.01 errD_z: 0.30 errG: 3.50
# Epoch:9 Iter: 1500 errD_x: 0.00 errD_z: 0.24 errG: 3.87
# Epoch:9 Iter: 1600 errD_x: 0.15 errD_z: 0.25 errG: 4.03
# Epoch:9 Iter: 1700 errD_x: 0.20 errD_z: 0.09 errG: 4.25
# Epoch:9 Iter: 1800 errD_x: 0.10 errD_z: 0.04 errG: 4.57
# Epoch:9 Iter: 1900 errD_x: 0.43 errD_z: 0.09 errG: 4.61
# Epoch:9 Iter: 2000 errD_x: 0.14 errD_z: 0.24 errG: 3.51
# Epoch:9 Iter: 2100 errD_x: 0.04 errD_z: 0.10 errG: 3.57
# Epoch:9 Iter: 2200 errD_x: 0.70 errD_z: 0.02 errG: 4.89
# Epoch:9 Iter: 2300 errD_x: 0.18 errD_z: 0.03 errG: 4.30
# Epoch:9 Iter: 2400 errD_x: 0.02 errD_z: 0.03 errG: 4.84
# Epoch:9 Iter: 2500 errD_x: 0.16 errD_z: 0.01 errG: 5.54
# Epoch:9 Iter: 2600 errD_x: 0.00 errD_z: 0.01 errG: 5.18
# Epoch:9 Iter: 2700 errD_x: 0.47 errD_z: 0.20 errG: 3.25
# Epoch:9 Iter: 2800 errD_x: 0.19 errD_z: 0.15 errG: 3.72
# Epoch:9 Iter: 2900 errD_x: 0.10 errD_z: 0.07 errG: 4.11
# Epoch:9 Iter: 3000 errD_x: 0.36 errD_z: 0.02 errG: 4.99
# Epoch:9 Iter: 3100 errD_x: 0.01 errD_z: 0.17 errG: 3.66
# Epoch:9 Iter: 3200 errD_x: 0.00 errD_z: 0.15 errG: 4.25
# Epoch:9 Iter: 3300 errD_x: 0.00 errD_z: 0.13 errG: 3.92
# Epoch:9 Iter: 3400 errD_x: 0.03 errD_z: 0.05 errG: 4.54
# Epoch:9 Iter: 3500 errD_x: 0.22 errD_z: 0.05 errG: 4.18
# Epoch:9 Iter: 3600 errD_x: 0.02 errD_z: 0.18 errG: 4.02
# Epoch:9 Iter: 3700 errD_x: 0.00 errD_z: 0.06 errG: 4.12
# Epoch:10 Iter: 100 errD_x: 0.05 errD_z: 0.05 errG: 4.80
# Epoch:10 Iter: 200 errD_x: 0.06 errD_z: 0.04 errG: 4.35
# Epoch:10 Iter: 300 errD_x: 0.26 errD_z: 0.07 errG: 5.27
# Epoch:10 Iter: 400 errD_x: 0.08 errD_z: 0.07 errG: 4.04
# Epoch:10 Iter: 500 errD_x: 0.16 errD_z: 0.14 errG: 3.40
# Epoch:10 Iter: 600 errD_x: 0.16 errD_z: 0.03 errG: 4.58
# Epoch:10 Iter: 700 errD_x: 0.42 errD_z: 0.02 errG: 4.69
# Epoch:10 Iter: 800 errD_x: 0.19 errD_z: 0.13 errG: 3.41
# Epoch:10 Iter: 900 errD_x: 0.04 errD_z: 0.03 errG: 4.96
# Epoch:10 Iter: 1000 errD_x: 0.21 errD_z: 0.08 errG: 3.54
# Epoch:10 Iter: 1100 errD_x: 0.21 errD_z: 0.06 errG: 4.64
# Epoch:10 Iter: 1200 errD_x: 0.35 errD_z: 0.05 errG: 4.03
# Epoch:10 Iter: 1300 errD_x: 0.00 errD_z: 0.04 errG: 4.31
# Epoch:10 Iter: 1400 errD_x: 0.06 errD_z: 0.12 errG: 3.74
# Epoch:10 Iter: 1500 errD_x: 0.09 errD_z: 0.04 errG: 4.43
# Epoch:10 Iter: 1600 errD_x: 0.12 errD_z: 0.02 errG: 4.85
# Epoch:10 Iter: 1700 errD_x: 0.33 errD_z: 0.06 errG: 3.79
# Epoch:10 Iter: 1800 errD_x: 0.03 errD_z: 0.13 errG: 3.83
# Epoch:10 Iter: 1900 errD_x: 0.00 errD_z: 0.03 errG: 4.60
# Epoch:10 Iter: 2000 errD_x: 0.10 errD_z: 0.04 errG: 4.19
# Epoch:10 Iter: 2100 errD_x: 0.14 errD_z: 0.07 errG: 3.92
# Epoch:10 Iter: 2200 errD_x: 0.34 errD_z: 0.11 errG: 3.76
# Epoch:10 Iter: 2300 errD_x: 0.04 errD_z: 0.11 errG: 4.13
# Epoch:10 Iter: 2400 errD_x: 0.09 errD_z: 0.04 errG: 3.53
# Epoch:10 Iter: 2500 errD_x: 0.06 errD_z: 0.23 errG: 3.54
# Epoch:10 Iter: 2600 errD_x: 0.01 errD_z: 0.05 errG: 4.55
# Epoch:10 Iter: 2700 errD_x: 0.01 errD_z: 0.03 errG: 4.72
# Epoch:10 Iter: 2800 errD_x: 0.45 errD_z: 0.01 errG: 5.49
# Epoch:10 Iter: 2900 errD_x: 0.01 errD_z: 0.23 errG: 3.82
# Epoch:10 Iter: 3000 errD_x: 0.05 errD_z: 0.04 errG: 3.87
# Epoch:10 Iter: 3100 errD_x: 0.16 errD_z: 0.01 errG: 5.36
# Epoch:10 Iter: 3200 errD_x: 0.19 errD_z: 0.03 errG: 4.29
# Epoch:10 Iter: 3300 errD_x: 0.19 errD_z: 0.02 errG: 5.51
# Epoch:10 Iter: 3400 errD_x: 0.13 errD_z: 0.06 errG: 4.06
# Epoch:10 Iter: 3500 errD_x: 0.00 errD_z: 0.09 errG: 3.14
# Epoch:10 Iter: 3600 errD_x: 0.12 errD_z: 0.07 errG: 4.24
# Epoch:10 Iter: 3700 errD_x: 0.04 errD_z: 0.38 errG: 4.52
